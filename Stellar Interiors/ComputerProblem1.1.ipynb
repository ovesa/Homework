# %%
import mesa_reader as mr
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
plt.rc('text', usetex=True)
plt.style.use('classic')

# %%
h = mr.MesaData('LOGS/history.data')
h2 = mr.MesaData('/Users/oanavesa/Desktop/GradSchool/Second_Year/ASTR565/prob1.1.1/LOGS/history.data')

# %%
-0.135,-.170

# %%
plt.figure(figsize=(10,10),facecolor="white")
plt.plot(h.log_Teff, h.log_L, label='Track 1')
#plt.plot(h.star_age, h.log_L)
plt.plot(h2.log_Teff,h2.log_L,label='Track 2')
plt.xlabel(r'$\log (T_{eff})$', fontweight='bold', fontsize=18)
plt.ylabel(r'$\log \left( L/L_\odot \right)$', fontweight='bold', fontsize=18)
plt.title('Effects of Nuclear Burning', fontweight='bold', fontsize=18)
plt.legend(fancybox=True,framealpha=0.5,loc='best')
plt.gca().invert_xaxis()
#plt.ylim(-0.135,-0.170)
#plt.xlim(3.76,3.7)
plt.show()

# %%
plt.figure(figsize=(10,10),facecolor="white")
plt.plot(h.log_Teff, h.log_L, label='No Nuclear Burning')
#plt.plot(h.star_age, h.log_L)
plt.plot(h2.log_Teff,h2.log_L,label='Nuclear Burning')
plt.xlabel(r'$\log (T_{eff})$', fontweight='bold', fontsize=18)
plt.ylabel(r'$\log \left( L/L_\odot \right)$', fontweight='bold', fontsize=18)
plt.title('Affects of Nuclear Burning', fontweight='bold', fontsize=18)
plt.legend(fancybox=True,framealpha=0.5,loc='best')
plt.gca().invert_xaxis()
#plt.ylim(-0.135,-0.170)
#plt.xlim(3.76,3.7)
plt.show()

# %%
plt.figure(figsize=(10,10),facecolor="white")
plt.plot(h.log_Teff, h.log_L, label='Track 1')
#plt.plot(h.star_age, h.log_L)
plt.plot(h2.log_Teff,h2.log_L,label='Track 2')
plt.xlabel(r'$\log (T_{eff})$', fontweight='bold', fontsize=18)
plt.ylabel(r'$\log \left( L/L_\odot \right)$', fontweight='bold', fontsize=18)
plt.title('Affects of Nuclear Burning', fontweight='bold', fontsize=18)
plt.legend(fancybox=True,framealpha=0.5,loc='best')
plt.gca().invert_xaxis()
plt.ylim(-0.135,-0.170)
plt.xlim(3.76,3.73)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)

# %%
fig, ax1 = plt.subplots(figsize=(10,10),facecolor="white")
ax1.plot(h.log_Teff, h.log_L, label=r'No Nuclear Burning, $1 \times 10^{10}$ years old')
ax1.plot(h2.log_Teff,h2.log_L,label=r'Nuclear Burning, $1.7 \times 10^{8}$ years old ')
ax1.set_xlabel(r'$\log (T_{eff})$', fontweight='bold', fontsize=18)
ax1.set_ylabel(r'$\log \left( L/L_\odot \right)$', fontweight='bold', fontsize=18)
ax1.set_title('Effects of Nuclear Burning', fontweight='bold', fontsize=18)
ax1.legend(fancybox=True,framealpha=0.5,loc='best')
ax1.set_ylim(top=0.9)
ax1.set_xlim(3.7,4.9)
ax1.invert_xaxis()

ax2 = plt.axes([0,0,1,1])
# Manually set the position and relative size of the inset axes within ax1
ip = InsetPosition(ax1, [0.1,0.05,0.5,0.5])
ax2.set_axes_locator(ip)
# Mark the region corresponding to the inset axes on ax1 and draw lines
# in grey linking the two axes.
mark_inset(ax1, ax2, loc1=2, loc2=4, fc="none", ec='0.5')


#plt.figure(figsize=(10,10),facecolor="white")
ax2.plot(h.log_Teff, h.log_L, label='Track 1')
#plt.plot(h.star_age, h.log_L)
ax2.plot(h2.log_Teff,h2.log_L,label='Track 2')
#ax2.set_xlabel(r'$\log (T_{eff})$', fontweight='bold', fontsize=18)
#ax2.set_ylabel(r'$\log \left( L/L_\odot \right)$', fontweight='bold', fontsize=18)
#plt.title('Affects of Nuclear Burning', fontweight='bold', fontsize=18)
#plt.legend(fancybox=True,framealpha=0.5,loc='best')
ax2.invert_xaxis()
ax2.set_ylim(-0.135,-0.170)
ax2.set_xlim(3.76,3.74)
plt.savefig('Effectsofnuclearburning.png')
plt.show()

# %%
print(h.star_age[-1],h2.star_age[-1])
# Out:
# 10000000000.0 170410945.9358341

# %%
for i in range(0,len(h.log_Teff)):
    k = h.star_age[i]
    lum = h.log_L[i]
    rad = h.log_R[i]
    temp = h.log_Teff[i]
    m_t = np.max(temp)
    if temp >= np.max(h.log_Teff):
        print(temp,k, lum,rad)
        print(10**temp, 10**lum, 10**rad)
# Out:
# 4.317276073778466 97612190.41993316 0.092472391265193 -1.0650571154717097
# 20762.329247838486 1.2372925309410179 0.08608805275574542

# %%
# Out:
#   File "<ipython-input-26-1997be4362ab>", line 1
#     10**
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # time step is in years
# 4. How long does it roughly take for the model with no nuclear burning to get to its highest Teff .
#
# 97612190.41993316 years
#
# t_KH = 30 Myr (M/M_0)^{2} (R/R_0)^{-1} (L/L_0)^{-1}

# %%
tkh = (1)**2*(0.08608805275574542)**(-1)*(1.2372925309410179)**(-1)*30

# %%
print(tkh)
# Out:
# 281.6475507690351

# %%
plt.figure(figsize=(10,10),facecolor="white")
plt.plot(np.log10(h.star_age),h.log_cntr_Rho, label=r'No Nuclear Burning, $1 \times 10^{10}$ years old')
plt.plot(np.log10(h2.star_age),h2.log_cntr_Rho, label=r'Nuclear Burning, $1.7 \times 10^{8}$ years old ')


plt.xlabel('log(star age)', fontweight='bold', fontsize=18)
plt.ylabel(r'$\log( \rho)$', fontweight='bold', fontsize=18)
plt.title('Interior Parameters', fontweight='bold', fontsize=18)
plt.legend(fancybox=True,framealpha=0.5,loc='best')
plt.savefig('densitycomp.png')
plt.show()

# %%
plt.figure(figsize=(10,10),facecolor="white")
plt.plot(np.log10(h.star_age),h.log_cntr_T,label=r'No Nuclear Burning, $1 \times 10^{10}$ years old')
plt.plot(np.log10(h2.star_age),h2.log_cntr_T,label=r'Nuclear Burning, $1.7 \times 10^{8}$ years old ')


plt.xlabel('log(star age)', fontweight='bold', fontsize=18)
plt.ylabel(r'$\log( T)$', fontweight='bold', fontsize=18)
plt.title('Interior Parameters', fontweight='bold', fontsize=18)
plt.legend(fancybox=True,framealpha=0.5,loc='best')
plt.savefig('tempcomp.png')

plt.show()

# %%
plt.figure(figsize=(10,10),facecolor="white")
plt.plot(np.log10(h.star_age),h.log_cntr_P, label=r'No Nuclear Burning, $1 \times 10^{10}$ years old')
plt.plot(np.log10(h2.star_age),h2.log_cntr_P,label=r'Nuclear Burning, $1.7 \times 10^{8}$ years old ')

plt.xlabel('log(star age)', fontweight='bold', fontsize=18)
plt.ylabel(r'$\log( P)$', fontweight='bold', fontsize=18)
plt.title('Interior Parameters', fontweight='bold', fontsize=18)
plt.legend(fancybox=True,framealpha=0.5,loc='best')
plt.savefig('pressurecomp.png')

plt.show()

# %%
plt.figure(figsize=(10,10),facecolor="white")
plt.plot(np.log10(h.star_age),h.log_L, label=r'No Nuclear Burning, $1 \times 10^{10}$ years old')
plt.plot(np.log10(h2.star_age),h2.log_L,label=r'Nuclear Burning, $1.7 \times 10^{8}$ years old ')

plt.xlabel('log(star age)', fontweight='bold', fontsize=18)
plt.ylabel(r'$\log( L/L_\odot)$', fontweight='bold', fontsize=18)
plt.title('Interior Parameters', fontweight='bold', fontsize=18)
plt.legend(fancybox=True,framealpha=0.5,loc='best')

plt.show()
